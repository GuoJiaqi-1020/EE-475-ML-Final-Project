# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import sklearn.tree as tree
import sklearn.svm as svm
import sklearn.ensemble as ensemble
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
import os
from lib_fun import *

# %%
# Decision Tree
data_path = '../Data/Pixel20/'
data, labels = load(data_path)
x = Flatten(RGBtoGray(data)) 
x_train, x_test , y_train, y_test = train_test_split(x,labels, test_size = 0.2)
clf = make_pipeline( StandardScaler(), tree.DecisionTreeClassifier())
clf.fit(x_train, y_train)
predict = clf.predict(x_test)
print(metrics.accuracy_score(y_test, predict))
# Out:
# (4559, 20, 20, 3) (4559,)
# 0.7960526315789473

# %%
confusion = metrics.confusion_matrix(y_test, predict)
plot_confusion(confusion)

# %%
data_path = '../Data/Pixel50/'
data, labels = load(data_path)
x = Flatten(RGBtoGray(data)) 
x_train, x_test , y_train, y_test = train_test_split(x,labels, test_size = 0.2)
clf = make_pipeline( StandardScaler(), tree.DecisionTreeClassifier())
clf.fit(x_train, y_train)
predict = clf.predict(x_test)
print(metrics.accuracy_score(y_test, predict)) 
confusion = metrics.confusion_matrix(y_test, predict)
plot_confusion(confusion)
# Out:
# (4559, 50, 50, 3) (4559,)
# 0.768640350877193

# %%
# Random Forest
data_path = '../Data/Pixel20/'
data, labels = load(data_path)
x = Flatten(RGBtoGray(data)) 
x_train, x_test , y_train, y_test = train_test_split(x,labels, test_size = 0.2)
clf = make_pipeline( StandardScaler(), ensemble.RandomForestClassifier())
clf.fit(x_train, y_train)
predict = clf.predict(x_test)
print(metrics.accuracy_score(y_test, predict)) 
confusion = metrics.confusion_matrix(y_test, predict)
plot_confusion(confusion)
# Out:
# (4559, 20, 20, 3) (4559,)
# 0.9133771929824561

# %%
data_path = '../Data/Pixel50/'
data, labels = load(data_path)
x = Flatten(RGBtoGray(data)) 
x_train, x_test , y_train, y_test = train_test_split(x,labels, test_size = 0.2)
clf = make_pipeline( StandardScaler(), ensemble.RandomForestClassifier())
clf.fit(x_train, y_train)
predict = clf.predict(x_test)
print(metrics.accuracy_score(y_test, predict)) 
confusion = metrics.confusion_matrix(y_test, predict)
plot_confusion(confusion)
# Out:
# (4559, 50, 50, 3) (4559,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-199bf1b16b45> in <module>
#       1 data_path = '../Data/Pixel50/'
#       2 data, labels = load(data_path)
# ----> 3 x = Flatten(RGBtoGray(data))
#       4 x_train, x_test , y_train, y_test = train_test_split(x,labels, test_size = 0.2)
#       5 clf = make_pipeline( StandardScaler(), ensemble.RandomForestClassifier())
#
# /mnt/d/Northwestern_Local/21Fall/EE475_ML/EE-475-ML-Final-Project/Face_Masking_recognition/lib_fun.py in RGBtoGray(data)
#      12     new_data = np.zeros((1, data.shape[1], data.shape[2]))
#      13     for im in data:
# ---> 14         new_data = np.append(new_data, cv2.cvtColor(im.astype('float32'),cv2.COLOR_RGB2GRAY).reshape(1,data.shape[1], data.shape[2]), axis=0)
#      15     return new_data[1:,:,:]
#      16
#
# KeyboardInterrupt:
